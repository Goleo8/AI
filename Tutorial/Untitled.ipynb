# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_clipboard()

# %%
df['adjust_UB']=df['UBs']/df['PVs']*df['WPVs']

# %%
df
# Out:
#        UBs     PVs    WPVs      EM  adjust_UB
# 0   0.4846  0.4619  0.4579  0.5540   0.480403
# 1   0.6848  0.7705  0.7788  0.7908   0.692177
# 2   0.2867  0.2165  0.2054  0.3990   0.272001
# 3   0.4226  0.2997  0.3304  0.5074   0.465889
# 4   0.6477  0.6192  0.6160  0.7243   0.644353
# 5   0.5112  0.4968  0.5418  0.5811   0.557504
# 6   0.5037  0.5576  0.5439  0.5630   0.491324
# 7   0.0473  0.0345  0.0205  0.0000   0.028106
# 8   0.2698  0.0772  0.0671  0.3777   0.234502
# 9   0.6196  0.6661  0.6561  0.6945   0.610298
# 10  0.6905  0.7311  0.7110  0.7613   0.671516
# 11  0.6916  0.8156  0.8668  0.7638   0.735016
# 12  0.5701  0.5855  0.6051  0.6690   0.589184
# 13  0.2127  0.0887  0.0884  0.3091   0.211981
# 14  0.7383  0.7305  0.7493  0.8168   0.757301
